# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN','NAME'], axis = 1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_value_counts = application_df['APPLICATION_TYPE'].value_counts()
app_value_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = app_value_counts[app_value_counts < 160]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_value_count = application_df['CLASSIFICATION'].value_counts()
class_value_count
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1

class_value = class_value_count[class_value_count > 1]
class_value
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = class_value_count[class_value_count < 1000]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies = pd.get_dummies(application_df[['APPLICATION_TYPE','AFFILIATION','CLASSIFICATION','USE_CASE','ORGANIZATION','SPECIAL_CONSIDERATIONS','INCOME_AMT']])
other_df = application_df[['STATUS','ASK_AMT']]
application_df1 = pd.concat([other_df,application_dummies],axis = 1)
application_df1.head()
#application_dummies = pd.get_dummies(application_df[['APPLICATION_TYPE','CLASSIFICATION']])
# Out:
#    STATUS  ASK_AMT  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000                     1                     0
# 1       1   108590                     0                     0
# 2       1     5000                     0                     0
# 3       1     6692                     0                     0
# 4       1   142590                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  APPLICATION_TYPE_T2  ...  \
# 0                     0                     0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = application_df1.values
y = application_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# 1. Frist Neural Network Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 6
hidden_nodes_layer3 = 4

nn1 = tf.keras.models.Sequential()

# First hidden layer
nn1.add(tf.keras.layers.Dense(units = hidden_nodes_layer1 , activation = "relu",input_dim = number_input_features))

# Second hidden layer
nn1.add(tf.keras.layers.Dense(units =hidden_nodes_layer2 , activation = "relu",input_dim = number_input_features))

# Third hidden layer
nn1.add(tf.keras.layers.Dense(units =hidden_nodes_layer3 , activation = "relu",input_dim = number_input_features))

# Output layer
nn1.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 8)                 936
#
#  dense_6 (Dense)             (None, 6)                 54
#
#  dense_7 (Dense)             (None, 4)                 28
#
#  dense_8 (Dense)             (None, 1)                 5
#
# ...
# Total params: 1023 (4.00 KB)
# Trainable params: 1023 (4.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn1.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn1.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 6s 3ms/step - loss: 0.6241 - accuracy: 0.6523
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7276
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5608 - accuracy: 0.7317
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5558 - accuracy: 0.7321
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5525 - accuracy: 0.7331
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7337
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5490 - accuracy: 0.7339
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5480 - accuracy: 0.7340
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7342
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn1.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5592 - accuracy: 0.7271 - 392ms/epoch - 1ms/step
# Loss: 0.5592247247695923, Accuracy: 0.7271137237548828

# %% [markdown]
# 2. Second Neural Network Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 6


nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(tf.keras.layers.Dense(units = hidden_nodes_layer1 , activation = "relu",input_dim = number_input_features))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units =hidden_nodes_layer2 , activation = "relu",input_dim = number_input_features))


# Output layer
nn2.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 8)                 936
#
#  dense_13 (Dense)            (None, 6)                 54
#
#  dense_14 (Dense)            (None, 1)                 7
#
# ...
# Total params: 997 (3.89 KB)
# Trainable params: 997 (3.89 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn2.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6056 - accuracy: 0.7008
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5601 - accuracy: 0.7286
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5535 - accuracy: 0.7312
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7327
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7328
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5483 - accuracy: 0.7333
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5475 - accuracy: 0.7335
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5470 - accuracy: 0.7340
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7350
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5600 - accuracy: 0.7276 - 460ms/epoch - 2ms/step
# Loss: 0.5599515438079834, Accuracy: 0.727580189704895

# %%
# Export our model to HDF5 file

nn1.save('AlphabetSoupCharity_Optimization.h5')
